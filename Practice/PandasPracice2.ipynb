# %%
import pandas as pd

# %%
df=pd.read_csv("orders.csv")

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.tail()
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (40, 9)

# %%
df[['OrderID','Product','Price']]
# Out:
#     OrderID                Product   Price
# 0      1001                 Laptop  1200.0
# 1      1002             Headphones   150.0
# 2      1003           Office Chair   300.0
# 3      1004              Desk Lamp    45.0
# 4      1005               Keyboard    80.0
# 5      1006               Notebook     5.0
# 6      1007          Standing Desk   450.0
# 7      1008                Monitor   220.0
# 8      1009                    Pen     1.5
# 9      1010                  Mouse    35.0
# 10     1011                 Webcam    85.0
# 11     1012           File Cabinet   180.0
# 12     1013                Stapler    12.0
# 13     1014              USB Drive    25.0
# 14     1015              Bookshelf   280.0
# 15     1016          Printer Paper     8.0
# 16     1017         Wireless Mouse    45.0
# 17     1018         Desk Organizer    65.0
# 18     1019             Calculator    15.0
# 19     1020             Whiteboard   120.0
# 20     1021           Highlighters     3.5
# ...

# %%
df[['OrderID','Product']].where(df['Quantity']>5) # this replaces rows with Nan where ondition doesnt match
# Out:
#     OrderID        Product
# 0       NaN            NaN
# 1       NaN            NaN
# 2       NaN            NaN
# 3       NaN            NaN
# 4       NaN            NaN
# 5       NaN            NaN
# 6       NaN            NaN
# 7       NaN            NaN
# 8    1009.0            Pen
# 9       NaN            NaN
# 10      NaN            NaN
# 11      NaN            NaN
# 12      NaN            NaN
# 13      NaN            NaN
# 14      NaN            NaN
# 15   1016.0  Printer Paper
# 16      NaN            NaN
# 17      NaN            NaN
# 18      NaN            NaN
# 19      NaN            NaN
# 20   1021.0   Highlighters
# 21      NaN            NaN
# 22      NaN            NaN
# 23   1024.0   Sticky Notes
# 24      NaN            NaN
# 25      NaN            NaN
# 26      NaN            NaN
# 27   1028.0   Binder Clips
# 28      NaN            NaN
# 29      NaN            NaN
# 30      NaN            NaN
# 31      NaN            NaN
# 32      NaN            NaN
# ...

# %%
df[df['Quantity']>5] #filters out rows first hlf is row, col is emoty by default so all coloumns are shown
# Out:
#     OrderID    CustomerName        Product    Category  Quantity  Price  \
# 8      1009     Maria Rossi            Pen  Stationery        10    1.5
# 15     1016    Ahmed Hassan  Printer Paper  Stationery        20    8.0
# 20     1021  David Thompson   Highlighters  Stationery         8    3.5
# 23     1024      Zara Ahmed   Sticky Notes  Stationery        15    4.0
# 27     1028     Nina Petrov   Binder Clips  Stationery        12    2.5
# 33     1034    Alex Johnson    Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped   Country
# 8   2024-06-10     Yes     Italy
# 15  2024-06-17     Yes     Egypt
# 20  2024-06-22      No    Canada
# 23  2024-06-25      No  Pakistan
# 27  2024-06-29     Yes    Russia
# 33  2024-07-05     Yes       USA

# %%
df.loc[df['Quantity']>5, ['OrderID','Product']] # to ref with a condition and col use loc, to reference with index and col use iloc
# Out:
#     OrderID        Product
# 8      1009            Pen
# 15     1016  Printer Paper
# 20     1021   Highlighters
# 23     1024   Sticky Notes
# 27     1028   Binder Clips
# 33     1034    Index Cards

# %%
df[df['Country']=='USA']
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA

# %%
df.loc[df['Country']=='USA'] # using loc
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA

# %%
df.loc[df['Country']=='USA',['OrderID','Country']]
# Out:
#     OrderID Country
# 0      1001     USA
# 17     1018     USA
# 33     1034     USA

# %%
df[(df['Country']=='USA') & (df['Quantity']>5)]
# Out:
#     OrderID  CustomerName      Product    Category  Quantity  Price  \
# 33     1034  Alex Johnson  Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped Country
# 33  2024-07-05     Yes     USA

# %%
df[(df['Country']=='USA') | (df['Country']=='UK')]
# Out:
#     OrderID   CustomerName             Product     Category  Quantity   Price  \
# 0      1001     John Smith              Laptop  Electronics         1  1200.0
# 6      1007    Emily Davis       Standing Desk    Furniture         1   450.0
# 17     1018  Michael Brown      Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson         Index Cards   Stationery       100     0.8
# 35     1036  Emma Thompson  Desk Lamp with USB    Furniture         1    68.0
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 6   2024-06-08     Yes      UK
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA
# 35  2024-07-07      No      UK

# %%
df.sort_values('Price',ascending=True).head()
# Out:
#     OrderID    CustomerName       Product    Category  Quantity  Price  \
# 33     1034    Alex Johnson   Index Cards  Stationery       100    0.8
# 8      1009     Maria Rossi           Pen  Stationery        10    1.5
# 27     1028     Nina Petrov  Binder Clips  Stationery        12    2.5
# 20     1021  David Thompson  Highlighters  Stationery         8    3.5
# 23     1024      Zara Ahmed  Sticky Notes  Stationery        15    4.0
#
#      OrderDate Shipped   Country
# 33  2024-07-05     Yes       USA
# 8   2024-06-10     Yes     Italy
# 27  2024-06-29     Yes    Russia
# 20  2024-06-22      No    Canada
# 23  2024-06-25      No  Pakistan

# %%
df['TotalAmount']=df['Quantity']*df['Price']

# %%
df
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df['TotalAmount'].groupby(by=df['Country']).sum() #u create group and then specify what to do with that group
# Out:
# Country
# Argentina         22.0
# Australia         36.0
# Brazil            95.0
# Canada           328.0
# China            280.0
# Colombia          42.0
# Egypt            160.0
# France           160.0
# Germany          210.0
# India            360.0
# Iran              28.0
# Italy             33.0
# Japan            105.0
# Mexico           160.0
# Morocco           32.0
# Pakistan          60.0
# Poland            90.0
# Portugal         125.0
# Russia            30.0
# Saudi Arabia     120.0
# Singapore        135.0
# South Korea      586.0
# Spain            125.0
# Sweden            28.0
# UAE              325.0
# UK               518.0
# USA             1345.0
# Ukraine           35.0
# Name: TotalAmount, dtype: float64

# %%
df.groupby(df['Country'])['TotalAmount'].sum()  #Another method
# Out:
# Country
# Argentina         22.0
# Australia         36.0
# Brazil            95.0
# Canada           328.0
# China            280.0
# Colombia          42.0
# Egypt            160.0
# France           160.0
# Germany          210.0
# India            360.0
# Iran              28.0
# Italy             33.0
# Japan            105.0
# Mexico           160.0
# Morocco           32.0
# Pakistan          60.0
# Poland            90.0
# Portugal         125.0
# Russia            30.0
# Saudi Arabia     120.0
# Singapore        135.0
# South Korea      586.0
# Spain            125.0
# Sweden            28.0
# UAE              325.0
# UK               518.0
# USA             1345.0
# Ukraine           35.0
# Name: TotalAmount, dtype: float64

# %%
df['Price'].groupby(df['Product']).mean()
# Out:
# Product
# Binder Clips                2.5
# Bluetooth Speaker          95.0
# Bookshelf                 280.0
# Calculator                 15.0
# Desk Calendar              18.0
# Desk Chair Mat             22.0
# Desk Clock                 35.0
# Desk Drawer Organizer      42.0
# Desk Lamp                  45.0
# Desk Lamp with USB         68.0
# Desk Organizer             65.0
# Desk Pad                   28.0
# Document Scanner          140.0
# File Cabinet              180.0
# Headphones                150.0
# Highlighters                3.5
# Index Cards                 0.8
# Keyboard                   80.0
# Laptop                   1200.0
# Monitor                   220.0
# Monitor Stand              55.0
# Mouse                      35.0
# Notebook                    5.0
# Office Chair              300.0
# Office Plant               35.0
# Paper Shredder             75.0
# Pen                         1.5
# Power Strip                18.0
# Printer Paper               8.0
# ...

# %%
df.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False).head(3)
# Out:
# Product
# Laptop           1200.0
# Standing Desk     450.0
# Monitor           440.0
# Name: TotalAmount, dtype: float64

# %%
df.groupby('Country')['OrderID'].count()
# Out:
# Country
# Argentina       1
# Australia       1
# Brazil          1
# Canada          2
# China           1
# Colombia        1
# Egypt           1
# France          2
# Germany         2
# India           1
# Iran            1
# Italy           2
# Japan           3
# Mexico          1
# Morocco         1
# Pakistan        1
# Poland          1
# Portugal        1
# Russia          1
# Saudi Arabia    1
# Singapore       1
# South Korea     3
# Spain           1
# Sweden          1
# UAE             2
# UK              2
# USA             3
# Ukraine         1
# Name: OrderID, dtype: int64

# %%
df.head()
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country  TotalAmount
# 0  2024-06-01     Yes        USA       1200.0
# 1  2024-06-03      No     Canada        300.0
# 2  2024-06-04     Yes        UAE        300.0
# 3  2024-06-05     Yes  Singapore        135.0
# 4  2024-06-06      No     Mexico        160.0

# %%
type(df['OrderDate'][1])
# Out:
# str

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])

# %%
df.loc[df['OrderDate'].dt.year>=2023]
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 0      1001        John Smith                 Laptop  Electronics         1
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# ...

# %%
df.isnull().sum()
# Out:
# OrderID         0
# CustomerName    0
# Product         0
# Category        0
# Quantity        0
# Price           0
# OrderDate       0
# Shipped         0
# Country         0
# TotalAmount     0
# dtype: int64

# %%
df[df['Price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerName, Product, Category, Quantity, Price, OrderDate, Shipped, Country, TotalAmount]
# Index: []

# %%
df['Price'].fillna(0)
# Out:
# 0     1200.0
# 1      150.0
# 2      300.0
# 3       45.0
# 4       80.0
# 5        5.0
# 6      450.0
# 7      220.0
# 8        1.5
# 9       35.0
# 10      85.0
# 11     180.0
# 12      12.0
# 13      25.0
# 14     280.0
# 15       8.0
# 16      45.0
# 17      65.0
# 18      15.0
# 19     120.0
# 20       3.5
# 21      95.0
# 22      35.0
# 23       4.0
# 24      28.0
# 25      75.0
# 26      22.0
# 27       2.5
# 28     110.0
# 29      18.0
# 30      32.0
# 31     140.0
# 32      42.0
# 33       0.8
# 34      55.0
# 35      68.0
# 36     125.0
# 37      28.0
# 38      18.0
# 39      35.0
# Name: Price, dtype: float64

# %%
df.Country.value_counts()
# Out:
# Country
# USA             3
# South Korea     3
# Japan           3
# Canada          2
# France          2
# UAE             2
# Italy           2
# UK              2
# Germany         2
# Singapore       1
# India           1
# Mexico          1
# Australia       1
# Spain           1
# Egypt           1
# China           1
# Poland          1
# Saudi Arabia    1
# Brazil          1
# Pakistan        1
# Sweden          1
# Argentina       1
# Russia          1
# Morocco         1
# Colombia        1
# Portugal        1
# Iran            1
# Ukraine         1
# Name: count, dtype: int64
