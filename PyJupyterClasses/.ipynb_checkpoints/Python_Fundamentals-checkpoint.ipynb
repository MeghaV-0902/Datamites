# %%
print("hello")
# Out:
# hello

# %%
a=20
b=33
c=0
c=a
a=b
b=c
print(a)
print(b)
# Out:
# 33
# 20

# %%
a=5
b=3
print("The value of a is : ",a," The value of B is :",b)
# Out:
# The value of a is :  5  The value of B is : 3
